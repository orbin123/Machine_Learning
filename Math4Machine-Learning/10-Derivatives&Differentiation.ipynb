# %% [markdown]
# # Derivatives and Differentiation

# %% [markdown]
# ### Computing derivatives with Differentiation

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>y</mi>
#   <mo>=</mo>
#   <msup>
#     <mi>x</mi>
#     <mn>2</mn>
#   </msup>
#   <mo>+</mo>
#   <mn>2</mn>
#   <mi>x</mi>
#   <mo>+</mo>
#   <mn>2</mn>
# </math>

# %%
import numpy as np

# TensorFlow
import tensorflow as tf
print(tf.__version__)

# PyTorch
import torch
print(torch.__version__)


import matplotlib.pyplot as plt
# Out:
# 2.17.0
# 2.5.1

# %%
x = np.linspace(-10, 10, 10000) # start, finish, n points

# %%
def f(my_x):
    my_y = my_x**2 + 2*my_x + 2
    return my_y

# %%
y = f(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
_ = ax.plot(x,y)

# %% [markdown]
# Let's identify the slope where, say, <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>x</mi>
#   <mo>=</mo>
#   <mn>2</mn>
# </math>.
#
# First, let's determine what y is:

# %%
f(2)
# Out:
# 10

# %% [markdown]
# Cool. Let's call this point P, which is located at (2, 10):

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10) # new
_ = ax.plot(x,y)

# %% [markdown]
# The delta method uses the difference between two points to calculate slope. To illustrate this, let's define another point, Q where, say, x=5.

# %%
f(5)
# Out:
# 37

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(5, 37, c = 'orange', zorder=3) # new
_ = ax.plot(x,y)

# %% [markdown]
# To find the slope  between points P and Q:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>m</mi>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <mtext>change in&#xA0;</mtext>
#       <mi>y</mi>
#     </mrow>
#     <mrow>
#       <mtext>change in&#xA0;</mtext>
#       <mi>x</mi>
#     </mrow>
#   </mfrac>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>y</mi>
#     </mrow>
#     <mrow>
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>x</mi>
#     </mrow>
#   </mfrac>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <msub>
#         <mi>y</mi>
#         <mn>2</mn>
#       </msub>
#       <mo>&#x2212;</mo>
#       <msub>
#         <mi>y</mi>
#         <mn>1</mn>
#       </msub>
#     </mrow>
#     <mrow>
#       <msub>
#         <mi>x</mi>
#         <mn>2</mn>
#       </msub>
#       <mo>&#x2212;</mo>
#       <msub>
#         <mi>x</mi>
#         <mn>1</mn>
#       </msub>
#     </mrow>
#   </mfrac>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <mn>37</mn>
#       <mo>&#x2212;</mo>
#       <mn>10</mn>
#     </mrow>
#     <mrow>
#       <mn>5</mn>
#       <mo>&#x2212;</mo>
#       <mn>2</mn>
#     </mrow>
#   </mfrac>
#   <mo>=</mo>
#   <mfrac>
#     <mn>27</mn>
#     <mn>3</mn>
#   </mfrac>
#   <mo>=</mo>
#   <mn>9</mn>
# </math>

# %%
m = (37-10)/(5-2)
m
# Out:
# 9.0

# %% [markdown]
# To plot the line that passes through P and Q, we can rearrange the equation of a line <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>y</mi>
#   <mo>=</mo>
#   <mi>m</mi>
#   <mi>x</mi>
#   <mo>+</mo>
#   <mi>b</mi>
# </math> to solve for b:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>b</mi>
#   <mo>=</mo>
#   <mi>y</mi>
#   <mo>&#x2212;</mo>
#   <mi>m</mi>
#   <mi>x</mi>
# </math>

# %%
b = 37-m*5
b
# Out:
# -8.0

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(5, 37, c='orange', zorder=3)
plt.ylim(-5, 150) # new
plt.plot(x, line_y, c='orange') # new
_ = ax.plot(x,y)

# %% [markdown]
# The closer Q becomes to P, the closer the slope  comes to being the true tangent of the point . Let's demonstrate this with another point Q at <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>x</mi>
#   <mo>=</mo>
#   <mn>2.1</mn>
# </math>.

# %% [markdown]
# Previously, our <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>x</mi>
# </math> between Q and P was equal to 3. Now it is much smaller:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>x</mi>
#   <mo>=</mo>
#   <msub>
#     <mi>x</mi>
#     <mn>2</mn>
#   </msub>
#   <mo>&#x2212;</mo>
#   <msub>
#     <mi>x</mi>
#     <mn>1</mn>
#   </msub>
#   <mo>=</mo>
#   <mn>2.1</mn>
#   <mo>&#x2212;</mo>
#   <mn>2</mn>
#   <mo>=</mo>
#   <mn>0.1</mn>
# </math>

# %%
f(2.1)
# Out:
# 10.61

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(2.1, 10.61, c = 'orange', zorder=3)
_ = ax.plot(x,y)

# %%
m = (10.61-10)/(2.1-2)
m
# Out:
# 6.099999999999989

# %%
b = 10.61-m*2.1
b
# Out:
# -2.199999999999978

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(2.1, 10.61, c='orange', zorder=3)
plt.ylim(-5, 150)
plt.plot(x, line_y, c='orange', zorder=3)
_ = ax.plot(x,y)

# %% [markdown]
# The closer Q becomes to P (i.e., <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>x</mi>
# </math> approaches 0), the clearer it becomes that the slope  at point P = (2, 10) is equal to 6.

# %% [markdown]
# Let's make <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>x</mi>
# </math> extremely small, 0.000001, to illustrate this:

# %%
delta_x = 0.000001
delta_x
# Out:
# 1e-06

# %%
x1 = 2
y1 = 10

# %% [markdown]
# Rearranging <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>x</mi>
#   <mo>=</mo>
#   <msub>
#     <mi>x</mi>
#     <mn>2</mn>
#   </msub>
#   <mo>&#x2212;</mo>
#   <msub>
#     <mi>x</mi>
#     <mn>1</mn>
#   </msub>
# </math>, we can calculate <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>x</mi>
#     <mn>2</mn>
#   </msub>
# </math> for our point <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>Q</mi>
# </math>, which is now extremely close to P:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <msub>
#     <mi>x</mi>
#     <mn>2</mn>
#   </msub>
#   <mo>=</mo>
#   <msub>
#     <mi>x</mi>
#     <mn>1</mn>
#   </msub>
#   <mo>+</mo>
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>x</mi>
# </math>

# %%
x2 = x1 + delta_x
x2
# Out:
# 2.000001

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>y</mi>
#     <mn>2</mn>
#   </msub>
# </math> for our point Q can be obtained with the usual function <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>f</mi>
#   <mo stretchy="false">(</mo>
#   <mi>x</mi>
#   <mo stretchy="false">)</mo>
# </math>:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <msub>
#     <mi>y</mi>
#     <mn>2</mn>
#   </msub>
#   <mo>=</mo>
#   <mi>f</mi>
#   <mo stretchy="false">(</mo>
#   <msub>
#     <mi>x</mi>
#     <mn>2</mn>
#   </msub>
#   <mo stretchy="false">)</mo>
# </math>

# %%
y2 = f(x2)
y2
# Out:
# 10.000006000001001

# %% [markdown]
# To find the slope <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>m</mi>
# </math>, we continue to use

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>m</mi>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>y</mi>
#     </mrow>
#     <mrow>
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>x</mi>
#     </mrow>
#   </mfrac>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <msub>
#         <mi>y</mi>
#         <mn>2</mn>
#       </msub>
#       <mo>&#x2212;</mo>
#       <msub>
#         <mi>y</mi>
#         <mn>1</mn>
#       </msub>
#     </mrow>
#     <mrow>
#       <msub>
#         <mi>x</mi>
#         <mn>2</mn>
#       </msub>
#       <mo>&#x2212;</mo>
#       <msub>
#         <mi>x</mi>
#         <mn>1</mn>
#       </msub>
#     </mrow>
#   </mfrac>
# </math>

# %%
m = (y2 - y1)/(x2 - x1)
m
# Out:
# 6.000001000088901

# %% [markdown]
# Using the delta method, we've shown that at point P, the slope of the curve is 6.

# %%
x1 = -1

# %%
y1 = f(x1)
y1
# Out:
# 1

# %% [markdown]
# Point P is located at (-1, 1)

# %%
delta_x
# Out:
# 1e-06

# %%
x2 = x1 + delta_x
x2
# Out:
# -0.999999

# %%
y2 = f(x2)
y2
# Out:
# 1.000000000001

# %% [markdown]
# Quick aside: Pertinent to defining differentiation as an equation, an alternative way to calculate <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>y</mi>
#     <mn>2</mn>
#   </msub>
# </math> is <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>f</mi>
#   <mo stretchy="false">(</mo>
#   <mi>x</mi>
#   <mo>+</mo>
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>x</mi>
#   <mo stretchy="false">)</mo>
# </math>

# %%
y2 = f(x1 + delta_x)
y2
# Out:
# 1.000000000001

# %% [markdown]
# Point Q is at (-0.999999, 1.000000000001), extremely close to P.

# %%
m = (y2-y1)/(x2-x1)
m
# Out:
# 1.0000889005535828e-06

# %% [markdown]
# Therefore, as <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>x</mi>
#     <mn>2</mn>
#   </msub>
# </math> becomes infinitely close to <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>x</mi>
#     <mn>1</mn>
#   </msub>
# </math>, it becomes clear that the slope m at <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>x</mi>
#     <mn>1</mn>
#   </msub>
#   <mo>=</mo>
#   <mo>&#x2212;</mo>
#   <mn>1</mn>
# </math> is equal to zero. Let's plot it out:

# %%
b = y2-m*x2
b
# Out:
# 1.0000010000889006

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(x1, y1)
plt.scatter(x2, y2, c='orange', zorder=3)
plt.ylim(-5, 150)
plt.plot(x, line_y, c='orange', zorder=3)
_ = ax.plot(x,y)

# %% [markdown]
# As  becomes infinitely close to :
#
# * <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>x</mi>
#     <mn>2</mn>
#   </msub>
# </math> - <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>x</mi>
#     <mn>1</mn>
#   </msub>
# </math> approaches 0
# In other words, <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>x</mi>
# </math> approaches 0
# This can be denoted as <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>x</mi>
#   <mo accent="false" stretchy="false">&#x2192;</mo>
#   <mn>0</mn>
# </math>

# %% [markdown]
# Using the delta method, we've derived the definition of differentiation from first principles. The derivative of y (denoted dy) with respect to x (denoted dx) can be represented as:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mfrac>
#     <mrow>
#       <mi>d</mi>
#       <mi>y</mi>
#     </mrow>
#     <mrow>
#       <mi>d</mi>
#       <mi>x</mi>
#     </mrow>
#   </mfrac>
#   <mo>=</mo>
#   <munder>
#     <mo data-mjx-texclass="OP" movablelimits="true">lim</mo>
#     <mrow data-mjx-texclass="ORD">
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>x</mi>
#       <mo accent="false" stretchy="false">&#x2192;</mo>
#       <mn>0</mn>
#     </mrow>
#   </munder>
#   <mfrac>
#     <mrow>
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>y</mi>
#     </mrow>
#     <mrow>
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>x</mi>
#     </mrow>
#   </mfrac>
# </math>

# %% [markdown]
# Expanding <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>y</mi>
# </math> out to <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>y</mi>
#     <mn>2</mn>
#   </msub>
#   <mo>&#x2212;</mo>
#   <msub>
#     <mi>y</mi>
#     <mn>1</mn>
#   </msub>
# </math>:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mfrac>
#     <mrow>
#       <mi>d</mi>
#       <mi>y</mi>
#     </mrow>
#     <mrow>
#       <mi>d</mi>
#       <mi>x</mi>
#     </mrow>
#   </mfrac>
#   <mo>=</mo>
#   <munder>
#     <mo data-mjx-texclass="OP" movablelimits="true">lim</mo>
#     <mrow data-mjx-texclass="ORD">
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>x</mi>
#       <mo accent="false" stretchy="false">&#x2192;</mo>
#       <mn>0</mn>
#     </mrow>
#   </munder>
#   <mfrac>
#     <mrow>
#       <msub>
#         <mi>y</mi>
#         <mn>2</mn>
#       </msub>
#       <mo>&#x2212;</mo>
#       <msub>
#         <mi>y</mi>
#         <mn>1</mn>
#       </msub>
#     </mrow>
#     <mrow>
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>x</mi>
#     </mrow>
#   </mfrac>
# </math>

# %% [markdown]
# Finally, replacing <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>y</mi>
#     <mn>1</mn>
#   </msub>
# </math> with <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>f</mi>
#   <mo stretchy="false">(</mo>
#   <mi>x</mi>
#   <mo stretchy="false">)</mo>
# </math> and replacing <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>y</mi>
#     <mn>2</mn>
#   </msub>
# </math> with <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>f</mi>
#   <mo stretchy="false">(</mo>
#   <mi>x</mi>
#   <mo>+</mo>
#   <mi mathvariant="normal">&#x394;</mi>
#   <mi>x</mi>
#   <mo stretchy="false">)</mo>
# </math>, we obtain a common representation of differentiation:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mfrac>
#     <mrow>
#       <mi>d</mi>
#       <mi>y</mi>
#     </mrow>
#     <mrow>
#       <mi>d</mi>
#       <mi>x</mi>
#     </mrow>
#   </mfrac>
#   <mo>=</mo>
#   <munder>
#     <mo data-mjx-texclass="OP" movablelimits="true">lim</mo>
#     <mrow data-mjx-texclass="ORD">
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>x</mi>
#       <mo accent="false" stretchy="false">&#x2192;</mo>
#       <mn>0</mn>
#     </mrow>
#   </munder>
#   <mfrac>
#     <mrow>
#       <mi>f</mi>
#       <mo stretchy="false">(</mo>
#       <mi>x</mi>
#       <mo>+</mo>
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>x</mi>
#       <mo stretchy="false">)</mo>
#       <mo>&#x2212;</mo>
#       <mi>f</mi>
#       <mo stretchy="false">(</mo>
#       <mi>x</mi>
#       <mo stretchy="false">)</mo>
#     </mrow>
#     <mrow>
#       <mi mathvariant="normal">&#x394;</mi>
#       <mi>x</mi>
#     </mrow>
#   </mfrac>
# </math>

# %%
def diff_demo(my_f, my_x, my_delta):
    return (my_f(my_x + my_delta) - my_f(my_x)) / my_delta

# %%
deltas = [1, 0.1, 0.01, 0.001, 0.0001, 0.00001, 0.000001]

# %%
for delta in deltas:
    print(diff_demo(f, 2, delta))
# Out:
# 7.0
# 6.099999999999994
# 6.009999999999849
# 6.000999999999479
# 6.000100000012054
# 6.000009999951316
# 6.000001000927568

# %%
for delta in deltas:
    print(diff_demo(f, -1, delta))
# Out:
# 1.0
# 0.10000000000000009
# 0.009999999999998899
# 0.001000000000139778
# 9.99999993922529e-05
# 1.000000082740371e-05
# 1.000088900582341e-06
