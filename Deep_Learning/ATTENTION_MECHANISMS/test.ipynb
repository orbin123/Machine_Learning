# %%
print('hello')
# Out:
# hello

# %%
import tensorflow as tf
from tensorflow.keras import layers 
from tensorflow.keras import models
import numpy as np 


# encoding 
class PositionalEncoding(models.Model):
    def __init__():
        pass


# transformer block 
class TransformerBlock(model.Model):
    def __init__(self,  d_model, n_heads):
        self.mha = layers.MultiHeadAttention()
        self.ffn = tf.keras.Sequential([
            layers.Dense(n_heads, activation='relu'),
            layers.Dense(d_model)
        ])
        self.n1 = layers.LayerNormalisation()
        self.n2 = layers.LayerNormalisation()
        self.d1 = layers.Dropout(0.1)
        self.d2 = layers.Dropout(0.1)

    def forward(self, x):
        outputs = self.mha(x, x, x)


# training
